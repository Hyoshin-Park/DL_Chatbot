# %%
# !pip install streamlit

# %%
# !pip install streamlit_chat

# %%
# !pip install sentence_transformers

# %%
# !python --version
# Out:
# Python 3.8.12

# %%
import streamlit as st
from streamlit_chat import message
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import json

# %%
df = pd.read_csv('wellness_dataset_original.csv')

df.head()
# Out:
#           구분                                               유저  \
# 0  감정/감정조절이상  제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1  감정/감정조절이상                         더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2  감정/감정조절이상                      하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 3  감정/감정조절이상                                꼭 롤러코스터 타는 것 같아요.
# 4  감정/감정조절이상                       롤러코스터 타는 것처럼 기분이 왔다 갔다 해요.
#
#                                         챗봇  Unnamed: 3
# 0          감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.         NaN
# 1                   저도 그 기분 이해해요. 많이 힘드시죠?         NaN
# 2  그럴 때는 밥은 잘 먹었는지, 잠은 잘 잤는지 체크해보는 것도 좋아요.         NaN
# 3                                      NaN         NaN
# 4                                      NaN         NaN

# %%
df = df.drop(columns=['Unnamed: 3'])

df.head()
# Out:
#           구분                                               유저  \
# 0  감정/감정조절이상  제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1  감정/감정조절이상                         더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2  감정/감정조절이상                      하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 3  감정/감정조절이상                                꼭 롤러코스터 타는 것 같아요.
# 4  감정/감정조절이상                       롤러코스터 타는 것처럼 기분이 왔다 갔다 해요.
#
#                                         챗봇
# 0          감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.
# 1                   저도 그 기분 이해해요. 많이 힘드시죠?
# 2  그럴 때는 밥은 잘 먹었는지, 잠은 잘 잤는지 체크해보는 것도 좋아요.
# 3                                      NaN
# 4                                      NaN

# %%
df = df[~df['챗봇'].isna()]

df.head()
# Out:
#              구분                                                 유저  \
# 0     감정/감정조절이상    제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1     감정/감정조절이상                           더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2     감정/감정조절이상                        하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 15  감정/감정조절이상/화  평소 다른 일을 할 때도 비슷해요. 생각한대로 안되면 화가 나고…그런 상황이 지속되...
# 16  감정/감정조절이상/화                              예전보다 화내는 게 과격해진 거 같아.
#
#                                             챗봇
# 0              감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.
# 1                       저도 그 기분 이해해요. 많이 힘드시죠?
# 2      그럴 때는 밥은 잘 먹었는지, 잠은 잘 잤는지 체크해보는 것도 좋아요.
# 15  화가 폭발할 것 같을 때는 그 자리를 피하는 것도 좋은 방법이라고 생각해요.
# 16         정말 힘드시겠어요. 화는 남에게도 스스로에게도 상처를 주잖아요.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1034 entries, 0 to 5215
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      1034 non-null   object
#  1   유저      1034 non-null   object
#  2   챗봇      1034 non-null   object
# dtypes: object(3)
# memory usage: 32.3+ KB

# %%
df.loc[0, '유저']
# Out:
# '제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.'

# %%
model = SentenceTransformer('jhgan/ko-sroberta-multitask')
# Out:
# 2022-06-21 17:08:22.635 INFO    sentence_transformers.SentenceTransformer: Load pretrained SentenceTransformer: jhgan/ko-sroberta-multitask
# 2022-06-21 17:08:37.417 INFO    sentence_transformers.SentenceTransformer: Use pytorch device: cpu

# %%
model.encode(df.loc[0, '유저'])
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# array([-4.80606616e-01, -2.94869274e-01,  4.37900156e-01, -6.40137792e-01,
#         3.28671336e-02, -3.42647165e-01, -5.47480918e-02,  1.73056610e-02,
#        -4.08221066e-01, -5.06034315e-01, -1.68733284e-01, -3.98677081e-01,
#        -1.24777012e-01, -9.71539840e-02, -1.65286452e-01,  5.72590018e-03,
#         6.13691173e-02, -1.91312343e-01,  2.53917247e-01, -5.85019886e-01,
#        -2.84425825e-01, -2.32035056e-01, -3.27080935e-01,  6.72978759e-02,
#        -1.64593966e-05, -4.72336441e-01, -3.60022008e-01,  2.91879743e-01,
#        -6.63861275e-01, -3.10574383e-01,  5.79525054e-01, -3.11722547e-01,
#         1.47698568e-02, -2.12172776e-01,  2.22057849e-01, -1.73828766e-01,
#        -3.78458500e-01, -4.20398384e-01, -2.38218829e-01,  6.38702959e-02,
#        -1.15304641e-01, -2.44564041e-01, -5.00228345e-01,  1.68355301e-01,
#        -6.58360064e-01, -8.91941905e-01, -6.26956940e-01, -3.21965396e-01,
# ...

# %%
df['embedding'] = pd.Series([[]] * len(df))

df['embedding'] = df['유저'].map(lambda x: list(model.encode(x)))

df.head()
# Out:
# ...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  7.99it/s]
#              구분                                                 유저  \
# 0     감정/감정조절이상    제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1     감정/감정조절이상                           더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2     감정/감정조절이상                        하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 15  감정/감정조절이상/화  평소 다른 일을 할 때도 비슷해요. 생각한대로 안되면 화가 나고…그런 상황이 지속되...
# 16  감정/감정조절이상/화                              예전보다 화내는 게 과격해진 거 같아.
#
#                                             챗봇  \
# 0              감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.
# 1                       저도 그 기분 이해해요. 많이 힘드시죠?
# 2      그럴 때는 밥은 잘 먹었는지, 잠은 잘 잤는지 체크해보는 것도 좋아요.
# 15  화가 폭발할 것 같을 때는 그 자리를 피하는 것도 좋은 방법이라고 생각해요.
# 16         정말 힘드시겠어요. 화는 남에게도 스스로에게도 상처를 주잖아요.
#
#                                             embedding
# 0   [-0.48060662, -0.29486927, 0.43790016, -0.6401...
# 1   [-1.1561571, -0.1450625, 0.2949036, -0.6739496...
# 2   [-0.6652001, -0.08126832, 1.0945566, 0.1057922...
# ...

# %%
df.to_csv('wellness_dataset.csv', index=False)

# %%
text = '요즘 머리가 아프고 너무 힘들어'

embedding = model.encode(text)
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 10.52it/s]

# %%
df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze())

df.head()
# Out:
#              구분                                                 유저  \
# 0     감정/감정조절이상    제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1     감정/감정조절이상                           더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2     감정/감정조절이상                        하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 15  감정/감정조절이상/화  평소 다른 일을 할 때도 비슷해요. 생각한대로 안되면 화가 나고…그런 상황이 지속되...
# 16  감정/감정조절이상/화                              예전보다 화내는 게 과격해진 거 같아.
#
#                                             챗봇  \
# 0              감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.
# 1                       저도 그 기분 이해해요. 많이 힘드시죠?
# 2      그럴 때는 밥은 잘 먹었는지, 잠은 잘 잤는지 체크해보는 것도 좋아요.
# 15  화가 폭발할 것 같을 때는 그 자리를 피하는 것도 좋은 방법이라고 생각해요.
# 16         정말 힘드시겠어요. 화는 남에게도 스스로에게도 상처를 주잖아요.
#
#                                             embedding  distance
# 0   [-0.48060662, -0.29486927, 0.43790016, -0.6401...  0.448967
# 1   [-1.1561571, -0.1450625, 0.2949036, -0.6739496...  0.490199
# 2   [-0.6652001, -0.08126832, 1.0945566, 0.1057922...  0.352131
# ...

# %%
answer = df.loc[df['distance'].idxmax()]

print('구분', answer['구분'])
print('유사한 질문', answer['유저'])
print('챗봇 답변', answer['챗봇'])
print('유사도', answer['distance'])
# Out:
# 구분 증상/편두통
# 유사한 질문 요즘은 머리가 한쪽만 지그시 누르는 것처럼 무겁고 아파요.
# 챗봇 답변 으으, 머리가 아프면 정말 힘들죠. 그 마음 정말 이해해요.
# 유사도 0.8296287059783936

# %%
text = '응 고마워' ## 답변을 받고자 하는 텍스트

embedding = model.encode(text) ## 텍스트 인코딩

df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze()) 
## 모든 질문&답변에 cosine_similarity 점수를 뽑음

answer = df.loc[df['distance'].idxmax()] ## 그 점수가 가장 높은 것을 답으로

print('구분: ', answer['구분'])
print('유사한 질문: ', answer['유저'])
print('챗봇 답변: ', answer['챗봇'])
print('유사도: ', answer['distance'])
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 15.86it/s]
# 구분:  배경/가족
# 유사한 질문:  누나가 혼내는 게 아니라, 다 이해한다고 그러는데 진심으로 고마웠어.
# 챗봇 답변:  그렇군요. 가족에 대해 더 말씀해주실 수 있으세요?
# 유사도:  0.5620124340057373

# %%
## KETI_대화데이터_일상_오피스

# %%
df1 = pd.read_table('./KETI_대화데이터_일상_오피스.txt', header=0)

df1.head()
# Out:
#    1    ﻿좋은 아침.
# 0  2     안녕하세요.
# 1  1     좋은 아침.
# 2  2     반갑습니다.
# 3  1     좋은 아침.
# 4  2  좋은 아침이에요.

# %%
df1 = df1.drop(index=0)

df1.head()
# Out:
#    1    ﻿좋은 아침.
# 1  1     좋은 아침.
# 2  2     반갑습니다.
# 3  1     좋은 아침.
# 4  2  좋은 아침이에요.
# 5  1     좋은 아침.

# %%
df1 = df1.reset_index()

# %%
df1.drop(columns=['index'], inplace=True)

# %%
df1
# Out:
#       1        ﻿좋은 아침.
# 0     1         좋은 아침.
# 1     2         반갑습니다.
# 2     1         좋은 아침.
# 3     2      좋은 아침이에요.
# 4     1         좋은 아침.
# ...  ..            ...
# 2643  2  아무 생각도 안하는걸요.
# 2644  1          넌 뭐야?
# 2645  2       잘 모르겠어요.
# 2646  1     기분이 영 별로야.
# 2647  2    무슨 일 있으신가요?
#
# [2648 rows x 2 columns]

# %%
tmp = df1.loc[0, '1']

# %%
type(tmp)
# Out:
# numpy.int64

# %%
user = df1[df1['1'] == 1]

# %%
chat = df1[df1['1'] == 2]

# %%
user.drop(columns=['1'], inplace=True)
chat.drop(columns=['1'], inplace=True)
user = user.reset_index()
chat = chat.reset_index()
# Out:
# C:\Users\nihso\AppData\Local\Temp\ipykernel_16308\2918487171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user.drop(columns=['1'], inplace=True)
# C:\Users\nihso\AppData\Local\Temp\ipykernel_16308\2918487171.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chat.drop(columns=['1'], inplace=True)

# %%
user.drop(columns=['index'], inplace=True)
chat.drop(columns=['index'], inplace=True)

# %%
user.rename(columns={'좋은 아침.':'user'}, inplace=True)
chat.rename(columns={'좋은 아침.':'chat'}, inplace=True)

# %%
user.columns = ['user']
chat.columns = ['chat']

# %%
df2 = user.join(chat, how='outer')

# %%
df2['구분'] = '일상'

# %%
df2 = df2[['구분', 'user', 'chat']]
df2
# Out:
#       구분          user           chat
# 0     일상        좋은 아침.         반갑습니다.
# 1     일상        좋은 아침.      좋은 아침이에요.
# 2     일상        좋은 아침.   간밤에 별일 없으셨죠?
# 3     일상        좋은 아침.       안녕하시렵니까?
# 4     일상        좋은 아침.         안녕하세요!
# ...   ..           ...            ...
# 1319  일상    눈 오는것 같은데?   네, 눈길 조심하세요.
# 1320  일상  너는 오늘 기분 어때?    기분 좋은 하루에요.
# 1321  일상       무슨 생각해?  아무 생각도 안하는걸요.
# 1322  일상         넌 뭐야?       잘 모르겠어요.
# 1323  일상    기분이 영 별로야.    무슨 일 있으신가요?
#
# [1324 rows x 3 columns]

# %%
df2.columns = ['구분', '유저', '챗봇']
df2
# Out:
#       구분            유저             챗봇
# 0     일상        좋은 아침.         반갑습니다.
# 1     일상        좋은 아침.      좋은 아침이에요.
# 2     일상        좋은 아침.   간밤에 별일 없으셨죠?
# 3     일상        좋은 아침.       안녕하시렵니까?
# 4     일상        좋은 아침.         안녕하세요!
# ...   ..           ...            ...
# 1319  일상    눈 오는것 같은데?   네, 눈길 조심하세요.
# 1320  일상  너는 오늘 기분 어때?    기분 좋은 하루에요.
# 1321  일상       무슨 생각해?  아무 생각도 안하는걸요.
# 1322  일상         넌 뭐야?       잘 모르겠어요.
# 1323  일상    기분이 영 별로야.    무슨 일 있으신가요?
#
# [1324 rows x 3 columns]

# %%
df2['embedding'] = pd.Series([[]] * len(df2))

df2['embedding'] = df2['유저'].map(lambda x: list(model.encode(x)))

df2.head()
# Out:
# ...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.93it/s]
# ...
# ...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  7.76it/s]
#    구분      유저            챗봇                                          embedding
# 0  일상  좋은 아침.        반갑습니다.  [-0.11503438, -0.33410618, 0.7883815, 0.650522...
# 1  일상  좋은 아침.     좋은 아침이에요.  [-0.11503438, -0.33410618, 0.7883815, 0.650522...
# 2  일상  좋은 아침.  간밤에 별일 없으셨죠?  [-0.11503438, -0.33410618, 0.7883815, 0.650522...
# 3  일상  좋은 아침.      안녕하시렵니까?  [-0.11503438, -0.33410618, 0.7883815, 0.650522...
# 4  일상  좋은 아침.        안녕하세요!  [-0.11503438, -0.33410618, 0.7883815, 0.650522...

# %%
text = '응 고마워' ## 답변을 받고자 하는 텍스트

embedding = model.encode(text) ## 텍스트 인코딩
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00,  7.81it/s]

# %%
df2['distance'] = df2['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze()) 
## 모든 질문&답변에 cosine_similarity 점수를 뽑음

answer = df2.loc[df2['distance'].idxmax()] ## 그 점수가 가장 높은 것을 답으로

# %%
print('구분: ', answer['구분'])
print('유사한 질문: ', answer['유저'])
print('챗봇 답변: ', answer['챗봇'])
print('유사도: ', answer['distance'])
# Out:
# 구분:  일상
# 유사한 질문:  고마워.
# 챗봇 답변:  천만에요.
# 유사도:  0.9630199074745178

# %%
df_total = pd.concat([df, df2], ignore_index=True)
df_total
# Out:
#                구분                                                 유저  \
# 0       감정/감정조절이상    제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1       감정/감정조절이상                           더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2       감정/감정조절이상                        하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 3     감정/감정조절이상/화  평소 다른 일을 할 때도 비슷해요. 생각한대로 안되면 화가 나고…그런 상황이 지속되...
# 4     감정/감정조절이상/화                              예전보다 화내는 게 과격해진 거 같아.
# ...           ...                                                ...
# 2353           일상                                         눈 오는것 같은데?
# 2354           일상                                       너는 오늘 기분 어때?
# 2355           일상                                            무슨 생각해?
# 2356           일상                                              넌 뭐야?
# 2357           일상                                         기분이 영 별로야.
#
#                                               챗봇  \
# 0                감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.
# ...

# %%
text = '배고파' ## 답변을 받고자 하는 텍스트

embedding = model.encode(text) ## 텍스트 인코딩

df_total['distance'] = df_total['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze()) 
## 모든 질문&답변에 cosine_similarity 점수를 뽑음

answer = df_total.loc[df_total['distance'].idxmax()] ## 그 점수가 가장 높은 것을 답으로

print('구분: ', answer['구분'])
print('유사한 질문: ', answer['유저'])
print('챗봇 답변: ', answer['챗봇'])
print('유사도: ', answer['distance'])
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 15.14it/s]
# 구분:  일상
# 유사한 질문:  배고파.
# 챗봇 답변:  오늘은 맛있는 걸로 든든하게 드세요.
# 유사도:  0.8323005437850952

# %%
text = '응 고마워' ## 답변을 받고자 하는 텍스트

embedding = model.encode(text) ## 텍스트 인코딩

df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze()) 
## 모든 질문&답변에 cosine_similarity 점수를 뽑음

answer = df.loc[df['distance'].idxmax()] ## 그 점수가 가장 높은 것을 답으로

print('구분: ', answer['구분'])
print('유사한 질문: ', answer['유저'])
print('챗봇 답변: ', answer['챗봇'])
print('유사도: ', answer['distance'])
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.65it/s]
# 구분:  배경/가족
# 유사한 질문:  누나가 혼내는 게 아니라, 다 이해한다고 그러는데 진심으로 고마웠어.
# 챗봇 답변:  그렇군요. 가족에 대해 더 말씀해주실 수 있으세요?
# 유사도:  0.5620124340057373

# %% [markdown]
# ## 유사한 질문지로 뽑아내는 것은 한계가 있기 때문에 말 자체를 학습 시키기

# %% [markdown]
# - 감정 상태 라벨링

# %% [markdown]
# ## 감성 대화 말뭉치 데이터를 통해 기쁨은 1 나머지는 모두 0으로 이진 분류해서 라벨링 해보기

# %%
df3 = pd.read_excel('./감성대화말뭉치(최종데이터)_Training.xlsx')
df3.head()
# Out:
#       번호   연령  성별       상황키워드    신체질환 감정_대분류   감정_소분류  \
# 0  44164   청년  남성  연애, 결혼, 출산    해당없음     기쁨     신이 난
# 1   3926   노년  남성      건강, 죽음  만성질환 유     불안  스트레스 받는
# 2  50882  청소년  여성     학업 및 진로    해당없음     당황       당황
# 3  31303   노년  남성          재정  만성질환 무     기쁨     신이 난
# 4  47200   노년  여성          재정  만성질환 유     기쁨       안도
#
#                                            사람문장1  \
# 0                      아내가 드디어 출산하게 되어서 정말 신이 나.
# 1        당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2        고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3  재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4                   빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
#
#                                     시스템응답1  \
# 0                아내분이 출산을 하시는군요. 정말 축하드려요.
# 1                       약 종류가 많아 번거로우시겠어요.
# 2  고등학교 수업이 중학교 때와는 다르게 갑자기 어려워서 당황스러우시군요.
# 3                  재취업 후 첫 월급이라 정말 기쁘시겠어요.
# 4           기분 좋으시겠어요. 앞으로는 어떻게 하실 생각이신가요?
#
#                                                사람문장2  \
# ...

# %%
df3
# Out:
#           번호   연령  성별       상황키워드    신체질환 감정_대분류   감정_소분류  \
# 0      44164   청년  남성  연애, 결혼, 출산    해당없음     기쁨     신이 난
# 1       3926   노년  남성      건강, 죽음  만성질환 유     불안  스트레스 받는
# 2      50882  청소년  여성     학업 및 진로    해당없음     당황       당황
# 3      31303   노년  남성          재정  만성질환 무     기쁨     신이 난
# 4      47200   노년  여성          재정  만성질환 유     기쁨       안도
# ...      ...  ...  ..         ...     ...    ...      ...
# 40874  50789   청년  남성        대인관계    해당없음     불안    혼란스러운
# 40875  48959   중년  남성          건강    해당없음     기쁨       안도
# 40876  36344  청소년  여성        가족관계    해당없음     슬픔      우울한
# 40877  14197   노년  여성          재정  만성질환 무     기쁨     감사하는
# 40878  16248   청년  남성        대인관계    해당없음     불안  스트레스 받는
#
#                                                    사람문장1  \
# 0                              아내가 드디어 출산하게 되어서 정말 신이 나.
# 1                당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2                고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# ...

# %%
df3.columns
# Out:
# Index(['번호', '연령', '성별', '상황키워드', '신체질환', '감정_대분류', '감정_소분류', '사람문장1',
#        '시스템응답1', '사람문장2', '시스템응답2', '사람문장3', '시스템응답3', '사람문장4', '시스템응답4'],
#       dtype='object')

# %%
df3 = df3[['감정_대분류', '사람문장1', '시스템응답1', '사람문장2', '시스템응답2', '사람문장3', '시스템응답3']]
df3
# Out:
#       감정_대분류                                              사람문장1  \
# 0         기쁨                          아내가 드디어 출산하게 되어서 정말 신이 나.
# 1         불안            당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2         당황            고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3         기쁨      재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4         기쁨                       빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# ...      ...                                                ...
# 40874     불안  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...
# 40875     기쁨                  지난주에 건강검진 결과가 나왔는데 정상이라고 결과가 나왔어.
# 40876     슬픔          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.
# 40877     기쁨            이렇게 좋은 운동 시설에서 경로 우대로 운동할 수 있다니 참 행운이야.
# 40878     불안                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.
#
#                                            시스템응답1  \
# 0                       아내분이 출산을 하시는군요. 정말 축하드려요.
# 1                              약 종류가 많아 번거로우시겠어요.
# ...

# %%
df3.loc[0, '시스템응답3']
# Out:
# '좋은 아빠가 되실 거 같아요. 진심으로 축하드려요.'

# %%
one = df3[['감정_대분류', '사람문장1', '시스템응답1']]
two = df3[['감정_대분류', '사람문장2', '시스템응답2']]
three = df3[['감정_대분류', '사람문장3', '시스템응답3']]

# %%
one.columns = ['구분', '유저', '챗봇']
two.columns = ['구분', '유저', '챗봇']
three.columns = ['구분', '유저', '챗봇']

# %%
# %%time
one['embedding'] = pd.Series([[]] * len(one))

one['embedding'] = one['유저'].map(lambda x: list(model.encode(x)))

one.head()
# Out:
# <timed exec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  8.47it/s]
# ...
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
two['embedding'] = pd.Series([[]] * len(two))

two['embedding'] = two['유저'].map(lambda x: list(model.encode(x)))

two.head()

# %%
three['embedding'] = pd.Series([[]] * len(three))

three['embedding'] = three['유저'].map(lambda x: list(model.encode(x)))

three.head()

# %%
df4 = pd.concat([one, two, three], ignore_index=True)
df4

# %%
def chat(text):
    embedding = model.encode(text) ## 텍스트 인코딩

    df4['distance'] = df4['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze()) 
    ## 모든 질문&답변에 cosine_similarity 점수를 뽑음

    answer = df4.loc[df4['distance'].idxmax()] ## 그 점수가 가장 높은 것을 답으로

    print('구분: ', answer['구분'])

# %%
while True:
    req = input('대화를 입력해보세요. ')
    if req == 'exit':
        break
    else:
        print('chatbot : ', chat(req))

# %%
text = '배고파' ## 답변을 받고자 하는 텍스트

embedding = model.encode(text) ## 텍스트 인코딩

df4['distance'] = df4['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze()) 
## 모든 질문&답변에 cosine_similarity 점수를 뽑음

answer = df4.loc[df4['distance'].idxmax()] ## 그 점수가 가장 높은 것을 답으로

print('구분: ', answer['구분'])
print('유사한 질문: ', answer['유저'])
print('챗봇 답변: ', answer['챗봇'])
print('유사도: ', answer['distance'])

# %%
def emotion_to_label(emotion):
    if emotion == '기쁨':
        return 1
    else:
        return 0

df3['이진 분류 감정'] = df3['감정_대분류'].apply(lambda x: emotion_to_label(x))
# Out:
# C:\Users\nihso\AppData\Local\Temp\ipykernel_16308\2578019391.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['이진 분류 감정'] = df3['감정_대분류'].apply(lambda x: emotion_to_label(x))

# %%
df3
# Out:
#       감정_대분류                                              사람문장1  \
# 0         기쁨                          아내가 드디어 출산하게 되어서 정말 신이 나.
# 1         불안            당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2         당황            고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3         기쁨      재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4         기쁨                       빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# ...      ...                                                ...
# 40874     불안  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...
# 40875     기쁨                  지난주에 건강검진 결과가 나왔는데 정상이라고 결과가 나왔어.
# 40876     슬픔          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.
# 40877     기쁨            이렇게 좋은 운동 시설에서 경로 우대로 운동할 수 있다니 참 행운이야.
# 40878     불안                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.
#
#                                            시스템응답1  \
# 0                       아내분이 출산을 하시는군요. 정말 축하드려요.
# 1                              약 종류가 많아 번거로우시겠어요.
# ...

# %%
df3['이진 분류 감정'].value_counts()
# Out:
# 0    34149
# 1     6730
# Name: 이진 분류 감정, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x = df3.drop(['감정_대분류', '이진 분류 감정'], axis=1)
y = df3['이진 분류 감정']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=13)

# %%
x_test.shape, y_test.shape
# Out:
# ((8176, 6), (8176,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# fit in training set
lr = LogisticRegression(random_state = 13)
lr.fit(x_train, y_train)

# predict in test set
y_pred = lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\nihso\Documents\ds_study\source_code\Deeplearning\DL_project.ipynb Cell 66' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/nihso/Documents/ds_study/source_code/Deeplearning/DL_project.ipynb#ch0000058?line=3'>4</a> # fit in training set
#       <a href='vscode-notebook-cell:/c%3A/Users/nihso/Documents/ds_study/source_code/Deeplearning/DL_project.ipynb#ch0000058?line=4'>5</a> lr = LogisticRegression(random_state = 13)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nihso/Documents/ds_study/source_code/Deeplearning/DL_project.ipynb#ch0000058?line=5'>6</a> lr.fit(x_train, y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/nihso/Documents/ds_study/source_code/Deeplearning/DL_project.ipynb#ch0000058?line=7'>8</a> # predict in test set
# ...

# %%
df3
# Out:
#       감정_대분류                                              사람문장1  \
# 0         기쁨                          아내가 드디어 출산하게 되어서 정말 신이 나.
# 1         불안            당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2         당황            고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3         기쁨      재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4         기쁨                       빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# ...      ...                                                ...
# 40874     불안  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...
# 40875     기쁨                  지난주에 건강검진 결과가 나왔는데 정상이라고 결과가 나왔어.
# 40876     슬픔          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.
# 40877     기쁨            이렇게 좋은 운동 시설에서 경로 우대로 운동할 수 있다니 참 행운이야.
# 40878     불안                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.
#
#                                            시스템응답1  \
# 0                       아내분이 출산을 하시는군요. 정말 축하드려요.
# 1                              약 종류가 많아 번거로우시겠어요.
# ...

# %%
@st.cache(allow_output_mutation=True)
def cached_model():
    model = SentenceTransformer('jhgan/ko-sroberta-multitask')
    return model

@st.cache(allow_output_mutation=True)
def get_dataset():
    df = pd.read_csv('wellness_dataset.csv')
    df['embedding'] = df['embedding'].apply(json.loads)
    return df

model = cached_model()
df = get_dataset()

st.header('온기 챗봇')
st.markdown("온라인의 기적 1조!!")

if 'generated' not in st.session_state:
    st.session_state['generated'] = []

if 'past' not in st.session_state:
    st.session_state['past'] = []

with st.form('form', clear_on_submit=True):
    user_input = st.text_input('당신: ', '')
    submitted = st.form_submit_button('전송')

if submitted and user_input:
    embedding = model.encode(user_input)

    df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze())
    answer = df.loc[df['distance'].idxmax()]

    st.session_state.past.append(user_input)
    st.session_state.generated.append(answer['챗봇'])

for i in range(len(st.session_state['past'])):
    message(st.session_state['past'][i], is_user=True, key=str(i) + '_user')
    if len(st.session_state['generated']) > i:
        message(st.session_state['generated'][i], key=str(i) + '_bot')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\nihso\miniconda3\envs\ds_study\lib\site-packages\streamlit\legacy_caching\hashing.py:368, in _CodeHasher.to_bytes(self, obj, context)
#     366 try:
#     367     # Hash the input
# --> 368     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     370     # Hmmm... It's possible that the size calculation is wrong. When we
#     371     # call to_bytes inside _to_bytes things get double-counted.
#
# File c:\Users\nihso\miniconda3\envs\ds_study\lib\site-packages\streamlit\legacy_caching\hashing.py:634, in _CodeHasher._to_bytes(self, obj, context)
#     633 assert code is not None
# --> 634 if self._file_should_be_hashed(code.co_filename):
#     635     context = _get_context(obj)
#
# ...
